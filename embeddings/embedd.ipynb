# %%
import pandas as pd

dataset = pd.read_csv("arxiv_abstracts.csv")

abstracts = dataset["Abstract"]
abstracts.to_csv("abstracts.csv")
abstracts = pd.read_csv("abstracts.csv")

# %% [markdown]
# # Preprocessing

# %%
import re

# Define preprocessing function
def preprocess_text(text):
    if pd.isnull(text):  # Handle missing values
        return ""
    text = text.replace("\n", " ")  # Remove line breaks
    text = re.sub(r"http\S+", "", text)  # Remove URLs
    text = re.sub(r"[^a-zA-Z0-9\s]", "", text)  # Remove special characters
    text = re.sub(r"\s+", " ", text).strip()  # Remove extra spaces
    return text

# check if 'Abstract' column exists
if "Abstract" in abstracts.columns:
    # apply preprocessing
    abstracts["Cleaned abstract"] = abstracts["Abstract"].apply(preprocess_text)
    abstracts.drop(columns=["Abstract", "Unnamed: 0"], inplace=True)
    abstracts.to_csv("cleaned_abstracts.csv", index=False)
else:
    print("Error: Column 'Abstract' not found in the data.")

cleaned_abstracts = pd.read_csv("cleaned_abstracts.csv")
cleaned_abstracts_list = cleaned_abstracts["Cleaned abstract"].tolist()

# %% [markdown]
# # Text embeddings

# %%
#!pip install git+https://github.com/huggingface/transformers.git -q

# %%
import torch
from transformers import ModernBertModel, ModernBertConfig

# Initializing a ModernBert style configuration
configuration = ModernBertConfig()

# Initializing a model from the modernbert-base style configuration
model = ModernBertModel(configuration)

# %%
from transformers import AutoTokenizer

model_id = "answerdotai/ModernBERT-base"
tokenizer = AutoTokenizer.from_pretrained(model_id)

def modernbert_embedding(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True)
    with torch.no_grad():
        outputs = model(**inputs)
    token_embeddings = outputs.last_hidden_state.mean(1) # (batch_size, seq_length, hidden_size) -> (batch_size, hidden_size)
    return token_embeddings

# %%
import os

batch_size = 16
os.makedirs("embeddings", exist_ok=True)

for i in range(0, len(cleaned_abstracts_list), batch_size):
    batch = cleaned_abstracts_list[i:i + batch_size]
    batch_embeddings = modernbert_embedding(batch)
    batch_file_path = f"embeddings/batch_{i // batch_size}.pt"
    torch.save(batch_embeddings, batch_file_path)
    print(f"Processed batch {i // batch_size + 1}/{len(cleaned_abstracts_list) // batch_size + 1}")
# Out:
# Processed batch 1/350
# Processed batch 2/350
# Processed batch 3/350
# Processed batch 4/350
# Processed batch 5/350
# Processed batch 6/350
# Processed batch 7/350
# Processed batch 8/350
# Processed batch 9/350
# Processed batch 10/350
# Processed batch 11/350
# Processed batch 12/350
# Processed batch 13/350
# Processed batch 14/350
# Processed batch 15/350
# Processed batch 16/350
# Processed batch 17/350
# Processed batch 18/350
# Processed batch 19/350
# Processed batch 20/350
# Processed batch 21/350
# Processed batch 22/350
# Processed batch 23/350
# Processed batch 24/350
# Processed batch 25/350
# Processed batch 26/350
# Processed batch 27/350
# Processed batch 28/350
# Processed batch 29/350
# Processed batch 30/350
# Processed batch 31/350
# Processed batch 32/350
# Processed batch 33/350
# Processed batch 34/350
# Processed batch 35/350
# Processed batch 36/350
# Processed batch 37/350
# Processed batch 38/350
# Processed batch 39/350
# Processed batch 40/350
# Processed batch 41/350
# Processed batch 42/350
# Processed batch 43/350
# Processed batch 44/350
# Processed batch 45/350
# Processed batch 46/350
# Processed batch 47/350
# Processed batch 48/350
# Processed batch 49/350
# Processed batch 50/350
# Processed batch 51/350
# Processed batch 52/350
# Processed batch 53/350
# Processed batch 54/350
# Processed batch 55/350
# Processed batch 56/350
# Processed batch 57/350
# Processed batch 58/350
# Processed batch 59/350
# Processed batch 60/350
# Processed batch 61/350
# Processed batch 62/350
# Processed batch 63/350
# Processed batch 64/350
# Processed batch 65/350
# Processed batch 66/350
# Processed batch 67/350
# Processed batch 68/350
# Processed batch 69/350
# Processed batch 70/350
# Processed batch 71/350
# Processed batch 72/350
# Processed batch 73/350
# Processed batch 74/350
# Processed batch 75/350
# Processed batch 76/350
# Processed batch 77/350
# Processed batch 78/350
# Processed batch 79/350
# Processed batch 80/350
# Processed batch 81/350
# Processed batch 82/350
# Processed batch 83/350
# Processed batch 84/350
# Processed batch 85/350
# Processed batch 86/350
# Processed batch 87/350
# Processed batch 88/350
# Processed batch 89/350
# Processed batch 90/350
# Processed batch 91/350
# Processed batch 92/350
# Processed batch 93/350
# Processed batch 94/350
# Processed batch 95/350
# Processed batch 96/350
# Processed batch 97/350
# Processed batch 98/350
# Processed batch 99/350
# Processed batch 100/350
# Processed batch 101/350
# Processed batch 102/350
# Processed batch 103/350
# Processed batch 104/350
# Processed batch 105/350
# Processed batch 106/350
# Processed batch 107/350
# Processed batch 108/350
# Processed batch 109/350
# Processed batch 110/350
# Processed batch 111/350
# Processed batch 112/350
# Processed batch 113/350
# Processed batch 114/350
# Processed batch 115/350
# Processed batch 116/350
# Processed batch 117/350
# Processed batch 118/350
# Processed batch 119/350
# Processed batch 120/350
# Processed batch 121/350
# Processed batch 122/350
# Processed batch 123/350
# Processed batch 124/350
# Processed batch 125/350
# Processed batch 126/350
# Processed batch 127/350
# Processed batch 128/350
# Processed batch 129/350
# Processed batch 130/350
# Processed batch 131/350
# Processed batch 132/350
# Processed batch 133/350
# Processed batch 134/350
# Processed batch 135/350
# Processed batch 136/350
# Processed batch 137/350
# Processed batch 138/350
# Processed batch 139/350
# Processed batch 140/350
# Processed batch 141/350
# Processed batch 142/350
# Processed batch 143/350
# Processed batch 144/350
# Processed batch 145/350
# Processed batch 146/350
# Processed batch 147/350
# Processed batch 148/350
# Processed batch 149/350
# Processed batch 150/350
# Processed batch 151/350
# Processed batch 152/350
# Processed batch 153/350
# Processed batch 154/350
# Processed batch 155/350
# Processed batch 156/350
# Processed batch 157/350
# Processed batch 158/350
# Processed batch 159/350
# Processed batch 160/350
# Processed batch 161/350
# Processed batch 162/350
# Processed batch 163/350
# Processed batch 164/350
# Processed batch 165/350
# Processed batch 166/350
# Processed batch 167/350
# Processed batch 168/350
# Processed batch 169/350
# Processed batch 170/350
# Processed batch 171/350
# Processed batch 172/350
# Processed batch 173/350
# Processed batch 174/350
# Processed batch 175/350
# Processed batch 176/350
# Processed batch 177/350
# Processed batch 178/350
# Processed batch 179/350
# Processed batch 180/350
# Processed batch 181/350
# Processed batch 182/350
# Processed batch 183/350
# Processed batch 184/350
# Processed batch 185/350
# Processed batch 186/350
# Processed batch 187/350
# Processed batch 188/350
# Processed batch 189/350
# Processed batch 190/350
# Processed batch 191/350
# Processed batch 192/350
# Processed batch 193/350
# Processed batch 194/350
# Processed batch 195/350
# Processed batch 196/350
# Processed batch 197/350
# Processed batch 198/350
# Processed batch 199/350
# Processed batch 200/350
# Processed batch 201/350
# Processed batch 202/350
# Processed batch 203/350
# Processed batch 204/350
# Processed batch 205/350
# Processed batch 206/350
# Processed batch 207/350
# Processed batch 208/350
# Processed batch 209/350
# Processed batch 210/350
# Processed batch 211/350
# Processed batch 212/350
# Processed batch 213/350
# Processed batch 214/350
# Processed batch 215/350
# Processed batch 216/350
# Processed batch 217/350
# Processed batch 218/350
# Processed batch 219/350
# Processed batch 220/350
# Processed batch 221/350
# Processed batch 222/350
# Processed batch 223/350
# Processed batch 224/350
# Processed batch 225/350
# Processed batch 226/350
# Processed batch 227/350
# Processed batch 228/350
# Processed batch 229/350
# Processed batch 230/350
# Processed batch 231/350
# Processed batch 232/350
# Processed batch 233/350
# Processed batch 234/350
# Processed batch 235/350
# Processed batch 236/350
# Processed batch 237/350
# Processed batch 238/350
# Processed batch 239/350
# Processed batch 240/350
# Processed batch 241/350
# Processed batch 242/350
# Processed batch 243/350
# Processed batch 244/350
# Processed batch 245/350
# Processed batch 246/350
# Processed batch 247/350
# Processed batch 248/350
# Processed batch 249/350
# Processed batch 250/350
# Processed batch 251/350
# Processed batch 252/350
# Processed batch 253/350
# Processed batch 254/350
# Processed batch 255/350
# Processed batch 256/350
# Processed batch 257/350
# Processed batch 258/350
# Processed batch 259/350
# Processed batch 260/350
# Processed batch 261/350
# Processed batch 262/350
# Processed batch 263/350
# Processed batch 264/350
# Processed batch 265/350
# Processed batch 266/350
# Processed batch 267/350
# Processed batch 268/350
# Processed batch 269/350
# Processed batch 270/350
# Processed batch 271/350
# Processed batch 272/350
# Processed batch 273/350
# Processed batch 274/350
# Processed batch 275/350
# Processed batch 276/350
# Processed batch 277/350
# Processed batch 278/350
# Processed batch 279/350
# Processed batch 280/350
# Processed batch 281/350
# Processed batch 282/350
# Processed batch 283/350
# Processed batch 284/350
# Processed batch 285/350
# Processed batch 286/350
# Processed batch 287/350
# Processed batch 288/350
# Processed batch 289/350
# Processed batch 290/350
# Processed batch 291/350
# Processed batch 292/350
# Processed batch 293/350
# Processed batch 294/350
# Processed batch 295/350
# Processed batch 296/350
# Processed batch 297/350
# Processed batch 298/350
# Processed batch 299/350
# Processed batch 300/350
# Processed batch 301/350
# Processed batch 302/350
# Processed batch 303/350
# Processed batch 304/350
# Processed batch 305/350
# Processed batch 306/350
# Processed batch 307/350
# Processed batch 308/350
# Processed batch 309/350
# Processed batch 310/350
# Processed batch 311/350
# Processed batch 312/350
# Processed batch 313/350
# Processed batch 314/350
# Processed batch 315/350
# Processed batch 316/350
# Processed batch 317/350
# Processed batch 318/350
# Processed batch 319/350
# Processed batch 320/350
# Processed batch 321/350
# Processed batch 322/350
# Processed batch 323/350
# Processed batch 324/350
# Processed batch 325/350
# Processed batch 326/350
# Processed batch 327/350
# Processed batch 328/350
# Processed batch 329/350
# Processed batch 330/350
# Processed batch 331/350
# Processed batch 332/350
# Processed batch 333/350
# Processed batch 334/350
# Processed batch 335/350
# Processed batch 336/350
# Processed batch 337/350
# Processed batch 338/350
# Processed batch 339/350
# Processed batch 340/350
# Processed batch 341/350
# Processed batch 342/350
# Processed batch 343/350
# Processed batch 344/350
# Processed batch 345/350
# Processed batch 346/350
# Processed batch 347/350
# Processed batch 348/350
# Processed batch 349/350
# Processed batch 350/350
